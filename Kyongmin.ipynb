# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df.columns = [name.strip().lower().replace(' ','').replace('-','_')for name in df.columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6eb280c58a9d> in <module>
# ----> 1 df.columns = [name.strip().lower().replace(' ','').replace('-','_')for name in df.columns]
#
# NameError: name 'df' is not defined

# %%
"""
*Column Names and Descriptions*


id - Unique identifier for a house

date - Date house was sold

price - Sale price (prediction target)

bedrooms - Number of bedrooms

bathrooms - Number of bathrooms

sqft_living - Square footage of living space in the home

sqft_lot - Square footage of the lot

floors - Number of floors (levels) in house

waterfront - Whether the house is on a waterfront
Includes Duwamish, Elliott Bay, Puget Sound, Lake Union, Ship Canal, Lake Washington, 
Lake Sammamish, other lake, and river/slough waterfronts

view - Quality of view from house
Includes views of Mt. Rainier, Olympics, Cascades, Territorial, 
Seattle Skyline, Puget Sound, Lake Washington, Lake Sammamish, small lake / river / creek, and other

condition - How good the overall condition of the house is. Related to maintenance of house.

See the King County Assessor Website for further explanation of each condition code

grade - Overall grade of the house. Related to the construction and design of the house.

See the King County Assessor Website for further explanation of each building grade code

sqft_above - Square footage of house apart from basement

sqft_basement - Square footage of the basement

yr_built - Year when house was built

yr_renovated - Year when house was renovated

zipcode - ZIP Code used by the United States Postal Service

lat - Latitude coordinate

long - Longitude coordinate

sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors

sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors


"""
# Out:
# '\n*Column Names and Descriptions*\n\n\nid - Unique identifier for a house\n\ndate - Date house was sold\n\nprice - Sale price (prediction target)\n\nbedrooms - Number of bedrooms\n\nbathrooms - Number of bathrooms\n\nsqft_living - Square footage of living space in the home\n\nsqft_lot - Square footage of the lot\n\nfloors - Number of floors (levels) in house\n\nwaterfront - Whether the house is on a waterfront\nIncludes Duwamish, Elliott Bay, Puget Sound, Lake Union, Ship Canal, Lake Washington, \nLake Sammamish, other lake, and river/slough waterfronts\n\nview - Quality of view from house\nIncludes views of Mt. Rainier, Olympics, Cascades, Territorial, \nSeattle Skyline, Puget Sound, Lake Washington, Lake Sammamish, small lake / river / creek, and other\n\ncondition - How good the overall condition of the house is. Related to maintenance of house.\n\nSee the King County Assessor Website for further explanation of each condition code\n\ngrade - Overall grade of the house. Related to
# ...

# %%
df = pd.read_csv('data/kc_house_data.csv')

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
fig, ax = plt.subplots(figsize = (15, 9))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(abs(df.corr()), mask=mask,annot=True)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %%
#Looking at the graph below, we can see that the points are focused on the left hand side. This would be a good 
#time to check the logarithmic transformation. This should make it look normal. (skewed right)
plt.hist(df['price'], bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('Price');

# %%
#Example of good use for logarithm. 
plt.hist(np.log(df['price']), bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('Price');

# %%
plt.hist(df['sqft_living'], bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('Sq. Foot Living');

# %%
plt.hist(np.log(df['sqft_living']), bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('Sq. Foot Living');

# %%
plt.hist(df['sqft_living15'], bins = (round(len(df)**.5)));
plt.xlabel('Average sq ft interior housing for nearest 15 neighbors');
plt.ylabel('Frequency');

# %%
plt.hist(df['sqft_above'], bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('sq ft of house w/o basement');

# %%
plt.hist(np.log(df['sqft_above']), bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('sq ft of house w/o basement');

# %%
df['bathrooms']
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21592    2.50
# 21593    2.50
# 21594    0.75
# 21595    2.50
# 21596    0.75
# Name: bathrooms, Length: 21597, dtype: float64

# %%
bathroom_count = df['bathrooms'].values.tolist()

# %%
bathroom_count
# Out:
# [1.0,
#  2.25,
#  1.0,
#  3.0,
#  2.0,
#  4.5,
#  2.25,
#  1.5,
#  1.0,
#  2.5,
#  2.5,
#  1.0,
#  1.0,
#  1.75,
#  2.0,
#  3.0,
#  2.0,
#  1.0,
#  1.0,
#  1.0,
#  1.75,
#  2.75,
#  2.5,
#  1.5,
#  2.25,
#  2.0,
#  1.75,
#  1.0,
#  1.75,
#  2.5,
#  2.5,
#  1.5,
#  1.75,
#  1.0,
#  2.75,
#  2.5,
#  1.0,
#  2.0,
#  1.0,
#  2.5,
#  2.5,
#  2.25,
#  2.75,
#  1.0,
#  1.0,
#  2.5,
#  1.0,
#  2.5,
#  1.75,
#  2.5,
#  1.0,
#  2.5,
#  1.75,
#  1.75,
#  2.25,
#  2.5,
#  2.5,
#  2.5,
#  3.25,
#  3.0,
#  2.25,
#  1.75,
#  1.75,
#  1.75,
#  2.25,
#  2.75,
#  2.5,
#  2.5,
#  1.0,
#  2.25,
#  3.25,
#  2.0,
#  2.0,
#  2.5,
#  1.75,
#  4.0,
#  1.75,
#  1.0,
#  1.0,
#  2.5,
#  2.5,
#  2.5,
#  1.0,
#  1.5,
#  1.0,
#  1.5,
#  2.25,
#  3.25,
#  2.25,
#  1.75,
#  2.5,
#  2.75,
#  1.0,
#  1.5,
#  1.5,
#  2.5,
#  1.75,
#  1.5,
#  1.75,
#  2.5,
#  2.5,
#  2.0,
#  2.25,
#  2.5,
#  1.0,
#  2.5,
#  1.0,
#  1.75,
#  2.5,
#  1.75,
#  2.5,
#  1.75,
#  1.75,
#  1.75,
#  2.5,
#  3.5,
#  3.5,
#  1.0,
#  2.0,
#  1.0,
# ...

# %%
#Just testing some things out. Messing around here. 


d = bathroom_count




freq, bins, patches = plt.hist(x=d, edgecolor='white', label='Count of Bathrooms', 
                               bins=(round(len(df)**.5)))

df.groupby(int)


bin_centers = np.diff(bins)*0.5 + bins[:-1]
n = 0
for fr, x, patch in zip(freq, bin_centers, patches):
  height = int(freq[n])
  plt.annotate("{}".format(height),
               xy = (x, height),             # top left corner of the histogram bar
               xytext = (0,0.2),             # offsetting label position above its bar
               textcoords = "offset points", # Offset (in points) from the *xy* value
               ha = 'center', va = 'bottom')
  n = n+1








plt.xlabel('# Bathrooms in Home');
plt.ylabel('Frequency');
plt.xticks(np.arange(min(bathroom_count), max(bathroom_count)+1, 1.0))
plt.gcf().autofmt_xdate()
plt.legend()
plt.show;

# %%
#Do I need log for bathroom?
self = plt.hist(df['bathrooms'], bins = (round(len(df)**.5)));

plt.xlabel('# Bathrooms in Home');
plt.ylabel('Frequency');
plt.xticks(np.arange(min(bathroom_count), max(bathroom_count)+1, 1.0))

plt.show;

# %%
plt.hist(np.log(df['bathrooms']), bins = (round(len(df)**.5)));
plt.xlabel('Frequency');
plt.ylabel('# Bathrooms in Home');

# %%
plots = sns.barplot(x=df['grade'], y=sum(df['grade'].value_counts()), data=df)
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=8, xytext=(0, 10),
                   textcoords='offset points'), 
    plt.gcf().autofmt_xdate()
plt.show()

# %%
df['grade'].value_counts()
